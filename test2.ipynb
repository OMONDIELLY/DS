# %%
import pandas as pd
import numpy as np
import sklearn as sk
import matplotlib.pyplot as plt

# %%
test1= pd.read_csv("/home/elly/Documents/test.csv" , index_col =0)

# %%
test1.iloc[240:250]
# Out:
#           Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP002333    Male      No          0  Not Graduate            No
# LP002339    Male     Yes          0      Graduate            No
# LP002344    Male     Yes          0      Graduate            No
# LP002346    Male     Yes          0      Graduate           NaN
# LP002354  Female      No          0  Not Graduate            No
# LP002355     NaN     Yes          0      Graduate            No
# LP002358    Male     Yes          2      Graduate           Yes
# LP002360    Male     Yes        NaN      Graduate            No
# LP002375    Male     Yes          0  Not Graduate           Yes
# LP002376    Male      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP002333             3844                  0       105.0             360.0
# LP002339             3887               1517       105.0             360.0
# ...

# %%
test1 = test1.dropna()
##nans = nans = lambda test1: test1[test1.isnull().any(axis=0)]
##nans(test1)

# %%
test1.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
test1.shape
# Out:
# (289, 11)

# %%
test1.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       289.000000         289.000000  289.000000        289.000000
# mean       4637.352941        1528.262976  136.792388        342.671280
# std        4790.683934        2377.599209   59.699582         65.655503
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2875.000000           0.000000  102.000000        360.000000
# 50%        3833.000000         879.000000  126.000000        360.000000
# 75%        5000.000000        2400.000000  158.000000        360.000000
# max       72529.000000       24000.000000  460.000000        480.000000
#
#        Credit_History
# count      289.000000
# mean         0.840830
# std          0.366469
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
dict1= {"Graduate":1 , "Not Graduate":0}
test1.replace(dict1 , inplace = True)

# %%
test1["Education"].iloc[150:160]
# Out:
# Loan_ID
# LP002059    1
# LP002062    1
# LP002064    1
# LP002070    0
# LP002077    1
# LP002083    1
# LP002090    1
# LP002096    0
# LP002099    1
# LP002102    1
# Name: Education, dtype: int64

# %%
gender= test1["Gender"]
dict2= {"Male":1 , "Female":0}
gender.replace(dict2, inplace = True)

# %%
test1["Self_Employed"].iloc[5:15]
# Out:
# Loan_ID
# LP001055    No
# LP001056    No
# LP001067    No
# LP001078    No
# LP001096    No
# LP001099    No
# LP001105    No
# LP001107    No
# LP001108    No
# LP001115    No
# Name: Self_Employed, dtype: object

# %%
self = test1["Self_Employed"]
dict3 = {"No":1, "Yes":1}
self.replace(dict3, inplace= True)

# %%
self.head(5)
# Out:
# Loan_ID
# LP001015    1
# LP001022    1
# LP001031    1
# LP001051    1
# LP001054    1
# Name: Self_Employed, dtype: int64

# %%
test1.head(3)
# Out:
#           Gender Married Dependents  Education  Self_Employed  \
# Loan_ID
# LP001015       1     Yes          0          1              1
# LP001022       1     Yes          1          1              1
# LP001031       1     Yes          2          1              1
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001015             5720                  0       110.0             360.0
# LP001022             3076               1500       126.0             360.0
# LP001031             5000               1800       208.0             360.0
#
#           Credit_History Property_Area
# Loan_ID
# LP001015             1.0         Urban
# LP001022             1.0         Urban
# LP001031             1.0         Urban

# %%
marr= test1["Married"]
dict4 = {"Yes":1,"No":0}
marr.replace(dict4, inplace= True)

# %%
test1.tail(3)
# Out:
#           Gender  Married Dependents  Education  Self_Employed  \
# Loan_ID
# LP002975       1        1          0          1              1
# LP002986       1        1          0          1              1
# LP002989       1        0          0          1              1
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP002975             4158                709       115.0             360.0
# LP002986             5000               2393       158.0             360.0
# LP002989             9200                  0        98.0             180.0
#
#           Credit_History Property_Area
# Loan_ID
# LP002975             1.0         Urban
# LP002986             1.0         Rural
# LP002989             1.0         Rural

# %%
#test1["Property_Area"].str.lower()
test1["Property_Area"].str.strip().head(3)
# Out:
# Loan_ID
# LP001015    Urban
# LP001022    Urban
# LP001031    Urban
# Name: Property_Area, dtype: object

# %%
test1.iloc[200:210]
# Out:
#           Gender  Married Dependents  Education  Self_Employed  \
# Loan_ID
# LP002375       1        1          0          0              1
# LP002376       1        0          0          1              1
# LP002383       1        1         3+          1              1
# LP002389       0        0          1          1              1
# LP002394       1        1          2          1              1
# LP002397       0        1          1          1              1
# LP002400       0        1          0          1              1
# LP002402       1        1          0          1              1
# LP002412       1        1          0          1              1
# LP002417       1        1         3+          0              1
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP002375             3943                  0        64.0             360.0
# LP002376             2925                  0        40.0             180.0
# ...

# %%
test1.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
test1.to_csv('cleanfile.csv', encoding = 'utf-8')

# %%
test1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 289 entries, LP001015 to LP002989
# Data columns (total 11 columns):
# Gender               289 non-null int64
# Married              289 non-null int64
# Dependents           289 non-null object
# Education            289 non-null int64
# Self_Employed        289 non-null int64
# ApplicantIncome      289 non-null int64
# CoapplicantIncome    289 non-null int64
# LoanAmount           289 non-null float64
# Loan_Amount_Term     289 non-null float64
# Credit_History       289 non-null float64
# Property_Area        289 non-null object
# dtypes: float64(3), int64(6), object(2)
# memory usage: 27.1+ KB

# %%
cl = pd.read_csv("/home/elly/Documents/cleanfile.csv" , index_col = 0) #cl means clean dataset

# %%
cl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 289 entries, LP001015 to LP002989
# Data columns (total 11 columns):
# Gender               289 non-null int64
# Married              289 non-null int64
# Dependents           289 non-null object
# Education            289 non-null int64
# Self_Employed        289 non-null int64
# ApplicantIncome      289 non-null int64
# CoapplicantIncome    289 non-null int64
# LoanAmount           289 non-null float64
# Loan_Amount_Term     289 non-null float64
# Credit_History       289 non-null float64
# Property_Area        289 non-null object
# dtypes: float64(3), int64(6), object(2)
# memory usage: 27.1+ KB

# %%
###splitting dataset into training and testing data
#import hashlib

#def test_set_check(identifier, test_ratio, hash):   
   # return hash(np.int64(identifier)).digest()[-1] < 256 * test_ratio

#def split_train_test_by_id(data, test_ratio, id_column, hash=hashlib.md5):  
   # ids = data[id_column]   
    #in_test_set = ids.apply(lambda id_: test_set_check(id_, test_ratio, hash))  
    #return data.loc[~in_test_set], data.loc[in_test_set]

#def split_train_test(data, test_ratio): 
   # np.random.seed(42)
   # shuffled_indices = np.random.permutation(len(data))  
   # test_set_size = int(len(data) * test_ratio)    
   # test_indices = shuffled_indices[:test_set_size]  
   # train_indices = shuffled_indices[test_set_size:]   
   # return data.iloc[train_indices], data.iloc[test_indices]


from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(cl, test_size=0.2, random_state=42)

# %%
train_set, test_set = split_train_test(cl, 0.2) 
print(len(train_set), "train +", len(test_set), "test")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-16a11403aecd> in <module>
# ----> 1 train_set, test_set = split_train_test(cl, 0.2)
#       2 print(len(train_set), "train +", len(test_set), "test")
#
# NameError: name 'split_train_test' is not defined

# %%
md = train_set.copy()

# %%
md.plot(kind = "scatter" , x= "LoanAmount", y="Loan_Amount_Term")

# %%
from sklearn.preprocessing import LabelEncoder 
encoder = LabelEncoder() 
P_area = cl["Property_Area"] 
P_area_encoded = encoder.fit_transform(P_area) 
P_area_encoded

# %%
encoder.classes_

# %%
cl.head(3)
# Out:
#           Gender  Married Dependents  Education  Self_Employed  \
# Loan_ID
# LP001015       1        1          0          1              1
# LP001022       1        1          1          1              1
# LP001031       1        1          2          1              1
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001015             5720                  0       110.0             360.0
# LP001022             3076               1500       126.0             360.0
# LP001031             5000               1800       208.0             360.0
#
#           Credit_History Property_Area
# Loan_ID
# LP001015             1.0         Urban
# LP001022             1.0         Urban
# LP001031             1.0         Urban

# %%
cl["Married"].value_counts().plot.pie(autopct = "%.1f%%")
plt.title("Marriage Status")
# Out:
# Text(0.5, 1.0, 'Marriage Status')
